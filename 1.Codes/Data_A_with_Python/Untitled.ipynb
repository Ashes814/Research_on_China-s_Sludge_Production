# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']    #指定默认字体 SimHei为黑体
plt.rcParams['axes.unicode_minus']=False   #用来正常显示负号
matplotlib.rcParams['font.family'] = 'SimHei'  
matplotlib.rcParams['font.sans-serif'] = 'NSimSun,Times New Roman'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cafe76c39bb7> in <module>
#       5 plt.rcParams['font.sans-serif']=['SimHei']    #指定默认字体 SimHei为黑体
#       6 plt.rcParams['axes.unicode_minus']=False   #用来正常显示负号
# ----> 7 matplotlib.rcParams['font.family'] = 'SimHei'
#       8 matplotlib.rcParams['font.sans-serif'] = 'NSimSun,Times New Roman'
#
# NameError: name 'matplotlib' is not defined

# %%
#读取数据
prediction_pro = pd.read_csv('prediction_pro.csv', encoding='utf-8')
display(prediction_pro.info())
display(prediction_pro.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12555 entries, 0 to 12554
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12555 non-null  int64
#  1   PROVINCE    12555 non-null  object
#  2   SSP         12555 non-null  object
#  3   YEAR        12555 non-null  int64
#  4   GDP         12555 non-null  float64
#  5   POP         12555 non-null  int64
#  6   LDP         12555 non-null  float64
#  7   BA          12555 non-null  float64
#  8   CCF         12555 non-null  int64
#  9   人均CCF       12555 non-null  int64
#  10  GDP_CCF_P   12555 non-null  float64
#  11  GDP2        12555 non-null  float64
#  12  GDP_POP     12555 non-null  float64
#  13  GDP_LDP     12555 non-null  float64
#  14  GDP_BA      12555 non-null  float64
#  15  result      12555 non-null  float64
# dtypes: float64(9), int64(5), object(2)
# memory usage: 1.5+ MB
# None
#    Unnamed: 0 PROVINCE   SSP  YEAR          GDP       POP          LDP  \
# 0           0      安徽省  SSP1  2020  25098.66508  59553012  36771.85322
# 1           1      安徽省  SSP1  2021  26341.53474  59541502  39286.51899
# 2           2      安徽省  SSP1  2022  27563.63558  59499476  41743.54592
# 3           3      安徽省  SSP1  2023  28751.04266  59429980  44118.42901
# 4           4      安徽省  SSP1  2024  29889.35633  59336071  46390.03731
#
#             BA         CCF  人均CCF    GDP_CCF_P         GDP2       GDP_POP  \
# 0  2230.975467  3573180720     60  1505919.905  629942988.8  1.494700e+12
# 1  2283.182068  3572490120     60  1580492.084  661137358.1  1.494410e+12
# 2  2331.820763  3569968560     60  1653818.135  691810457.8  1.493360e+12
# 3  2376.956310  3565798800     60  1725062.560  721612790.4  1.491610e+12
# 4  2418.687370  3560164260     60  1793361.380  750182944.0  1.489260e+12
#
#         GDP_LDP       GDP_BA       result
# 0  9.229244e+08  55994506.05  398543.4670
# 1  9.860392e+08  57304822.04  426520.6095
# 2  1.047707e+09  58525588.36  428641.0090
# 3  1.107314e+09  59658430.33  449884.7035
# 4  1.164328e+09  60705824.23  557701.6555
