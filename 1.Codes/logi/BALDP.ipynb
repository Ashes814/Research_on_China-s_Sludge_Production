# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import matplotlib
plt.rcParams['font.sans-serif']=['SimHei']    #指定默认字体 SimHei为黑体
plt.rcParams['axes.unicode_minus']=False   #用来正常显示负号
matplotlib.rcParams['font.family'] = 'SimHei'  
matplotlib.rcParams['font.sans-serif'] = 'NSimSun,Times New Roman'
from scipy.optimize import leastsq

import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
 
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
BA = pd.read_csv('BA.csv', encoding = 'utf-8')
LDP = pd.read_csv('LDP.csv', encoding = 'utf-8')
display(BA.info())
display(BA.head())
display(LDP.info())
display(LDP.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xj/q_jj69d97y5cd2h3wn7zt0zc0000gn/T/ipykernel_59593/3537522287.py in <module>
# ----> 1 BA = pd.read_csv('BA.csv', encoding = 'utf-8')
#       2 LDP = pd.read_csv('LDP.csv', encoding = 'utf-8')
#       3 display(BA.info())
#       4 display(BA.head())
#       5 display(LDP.info())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1215             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217             self.handles = get_handle(  # type: ignore[call-overload]
#    1218                 f,
#    1219                 mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     787         if ioargs.encoding and "b" not in ioargs.mode:
#     788             # Encoding
# --> 789             handle = open(
#     790                 handle,
#     791                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'BA.csv'

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.115
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in BA :
    P = BA[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP1_BA = pd.DataFrame(d)
SSP1_BA.to_csv('SSP1_BA.csv', encoding='utf_8_sig')
SSP1_BA = SSP1_BA.drop(['YEAR', '全国'], axis=1)
display(SSP1_BA.loc[98].sum())

for i in SSP1_BA :
    SSP1_BA[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 79733.72295331722

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.1
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in BA :
    P = BA[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP4_BA = pd.DataFrame(d)
SSP4_BA.to_csv('SSP4_BA.csv', encoding='utf_8_sig')
SSP4_BA = SSP4_BA.drop(['YEAR', '全国'], axis=1)
display(SSP4_BA.loc[98].sum())

for i in SSP4_BA :
    SSP4_BA[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 91875.12329931071

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.09
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in BA :
    P = BA[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP3_BA = pd.DataFrame(d)
SSP3_BA.to_csv('SSP3_BA.csv', encoding='utf_8_sig')
SSP3_BA = SSP3_BA.drop(['YEAR', '全国'], axis=1)
display(SSP3_BA.loc[98].sum())

for i in SSP3_BA :
    SSP3_BA[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 110407.26893421805

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.0869
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in BA :
    P = BA[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP2_BA = pd.DataFrame(d)
SSP2_BA.to_csv('SSP2_BA.csv', encoding='utf_8_sig')
SSP2_BA = SSP2_BA.drop(['YEAR', '全国'], axis=1)
display(SSP2_BA.loc[98].sum())
for i in SSP2_BA :
    SSP2_BA[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 128130.63609104334

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.08598
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in BA :
    P = BA[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP5_BA = pd.DataFrame(d)
SSP5_BA.to_csv('SSP3_BA.csv', encoding='utf_8_sig')

SSP5_BA = SSP5_BA.drop(['YEAR', '全国'], axis=1)
display(SSP5_BA.loc[98].sum())
for i in SSP5_BA :
    SSP3_BA[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 142467.13792197942

# %%
SSP1_BA = SSP1_BA.drop(np.arange(0,18,1))
SSP2_BA = SSP2_BA.drop(np.arange(0,18,1))
SSP3_BA = SSP3_BA.drop(np.arange(0,18,1))
SSP4_BA = SSP4_BA.drop(np.arange(0,18,1))
SSP5_BA = SSP5_BA.drop(np.arange(0,18,1))
SSP1_BA.append(SSP2_BA).append(SSP3_BA).append(SSP4_BA).append(SSP5_BA).to_csv('SSPBA_coc.csv', encoding='utf_8_sig')

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.15
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in LDP :
    P = LDP[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP1_LDP = pd.DataFrame(d)

SSP1_LDP = SSP1_LDP.drop(['YEAR', '全国'], axis=1)
display(SSP1_LDP.loc[98].sum())

for i in SSP1_LDP :
    SSP1_LDP[i].plot(kind='line')
#SSP1_LDP.to_csv('SSP1_LDP.csv', encoding='utf_8_sig')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 1142424.1719029527

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.14
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in LDP :
    P = LDP[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP4_LDP = pd.DataFrame(d)
SSP4_LDP = SSP4_LDP.drop(['YEAR', '全国'], axis=1)
display(SSP4_LDP.loc[98].sum())
for i in SSP4_LDP :
    SSP4_LDP[i].plot(kind='line')
SSP4_LDP.to_csv('SSP4_LDP.csv', encoding='utf_8_sig')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 1315746.741094729

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.1325
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in LDP :
    P = LDP[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP3_LDP = pd.DataFrame(d)
SSP3_LDP.to_csv('SSP3_LDP.csv', encoding='utf_8_sig')

SSP3_LDP = SSP3_LDP.drop(['YEAR', '全国'], axis=1)
display(SSP3_LDP.loc[98].sum())
for i in SSP3_LDP :
    SSP3_LDP[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 1576081.0029726592

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.132
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in LDP :
    P = LDP[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP2_LDP = pd.DataFrame(d)
SSP2_LDP.to_csv('SSP2_LDP.csv', encoding='utf_8_sig')

SSP2_LDP = SSP2_LDP.drop(['YEAR', '全国'], axis=1)
display(SSP2_LDP.loc[98].sum())

for i in SSP2_LDP :
    SSP2_LDP[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 1604414.7996792672

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.1315
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
d = {}
for pro in LDP :
    P = LDP[pro]
    popt, pcov = curve_fit(logistic_increase_function, t, P)
    P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
    future=np.arange(1, 100, 1)
    future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
    d[pro] = future_predict
SSP5_LDP = pd.DataFrame(d)
SSP5_LDP.to_csv('SSP3_LDP.csv', encoding='utf_8_sig')
SSP5_LDP = SSP5_LDP.drop(['YEAR', '全国'], axis=1)
display(SSP5_LDP.loc[98].sum())
for i in SSP5_LDP :
    SSP3_LDP[i].plot(kind='line')
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 1635552.3839381388

# %%
def logistic_increase_function(t,K,P0,r):
    t0=1
    r=0.15
    # t:time   t0:initial time    P0:initial_value    K:capacity  r:increase_rate
    exp_value=np.exp(r*(t-t0))
    return (K*exp_value*P0)/(K+(exp_value-1)*P0)
t = np.arange(1, 19, 1)
P = LDP['全国']
popt, pcov = curve_fit(logistic_increase_function, t, P)
P_predict = logistic_increase_function(t,popt[0],popt[1],popt[2])
future=np.arange(1, 100, 1)
future_predict=logistic_increase_function(future,popt[0],popt[1],popt[2])
plot2 = plt.plot(t, P_predict, 'r',label='polyfit values')
plot3 = plt.plot(future, future_predict, 'r',label='polyfit values')
plt.show()

# %%
SSP1_LDP = SSP1_LDP.drop(np.arange(0,18,1))
SSP2_LDP = SSP2_LDP.drop(np.arange(0,18,1))
SSP3_LDP = SSP3_LDP.drop(np.arange(0,18,1))
SSP4_LDP = SSP4_LDP.drop(np.arange(0,18,1))
SSP5_LDP = SSP5_LDP.drop(np.arange(0,18,1))

# %%
SSP1_LDP.append(SSP2_LDP).append(SSP3_LDP).append(SSP4_LDP).append(SSP5_LDP).to_csv('SSPLDP_coc.csv', encoding='utf_8_sig')

# %%
print('1 \n 2')
# Out:
# 1
#  2

# %%
import pandas
pandas.__file__
# Out:
# '/Users/oo/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py'
